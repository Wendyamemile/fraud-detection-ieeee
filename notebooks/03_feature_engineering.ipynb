# %% [markdown]
# # Feature Engineering

# %%
import sys, os
sys.path.append(os.path.abspath("../src"))

from data_loading import load_data
from preprocessing import preprocess_pipeline

# %% [markdown]
# # Load data

# %%
df = load_data()
df_fe = preprocess_pipeline(df)

df_fe.shape
# Out:
# Data loaded: (590540, 434)
# Dropping 12 high-missing columns
# Encoded 29 categorical columns
# Starting feature engineering...
# Feature engineering completed
# Preprocessing completed
# (590540, 429)

# %%
df_fe[['time_since_last_txn', 'txn_count_5', 'amt_mean']].head()
# Out:
#         time_since_last_txn  txn_count_5    amt_mean
# 243924                  NaN            0   23.443000
# 36634                   NaN            0   79.666667
# 164336             127702.0            1   79.666667
# 223739              59403.0            2   79.666667
# 33767                   NaN            0  136.400000
