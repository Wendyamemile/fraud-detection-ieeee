# %% [markdown]
# # Preprocessing

# %%
import sys, os
sys.path.append(os.path.abspath("../src"))

from data_loading import load_data
from preprocessing import preprocess_pipeline

# %% [markdown]
# # Load data

# %%
df = load_data()
df_processed = preprocess_pipeline(df)

df_processed.shape
# Out:
# Data loaded: (590540, 434)
# Starting preprocessing...
# Dropping 12 high-missing columns
# Encoded 29 categorical columns
# Preprocessing completed
# (590540, 423)

# %%
df_processed.head()
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt  ProductCD  card1  \
# 0        2987000        0          86400            68.5          4  13926
# 1        2987001        0          86401            29.0          4   2755
# 2        2987002        0          86469            59.0          4   4663
# 3        2987003        0          86499            50.0          4  18132
# 4        2987004        0          86506            50.0          1   4497
#
#    card2  card3  card4  card5  ...  id_32  id_33  id_34  id_35  id_36  id_37  \
# 0  361.0  150.0      1  142.0  ...   24.0    260      4      2      2      2
# 1  404.0  150.0      2  102.0  ...   24.0    260      4      2      2      2
# 2  490.0  150.0      4  166.0  ...   24.0    260      4      2      2      2
# 3  567.0  150.0      2  117.0  ...   24.0    260      4      2      2      2
# 4  514.0  150.0      2  102.0  ...   32.0    164      3      1      0      1
#
#    id_38  DeviceType  DeviceInfo       hour
# 0      2           1        1735  13.722222
# 1      2           1        1735  13.722500
# 2      2           1        1735  13.722778
# 3      2           1        1735  13.723056
# 4      1           2         954  13.723333
#
# [5 rows x 423 columns]
